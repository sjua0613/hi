# %% [markdown]
# <a href="https://colab.research.google.com/github/sjua0613/hi/blob/main/pandas_02_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DataFrame**
# + 2차원 자료구조인 DataFrame는 행과 열이 있는 테이블 데이터

# %% [markdown]
# ## **pandas 라이브러리 추가**

# %%
import pandas as pd 
# as pd는 짧게 쓸려고
# as pd는 없어도 됨

# %% [markdown]
# ### 복습문제)
# 다음 4개의 리스트를 이용하여 각 지역별 평균, 최대, 최소값 리스트를 값으로 가지는 딕션너라를 작성하시오.
# * 데이터참고:https://www.airkorea.or.kr/web/weekSearch?pMENU_NO=111
# ```
# area = ['서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남','전북','전남','경북','경남','제주']
# pm25_avg = [20,13,15,20,19,16,14,18,20,14,19,23,23,14,15,13,14]
# pm25_max = [22,18,18,30,23,20,16,19,27,18,26,29,30,27,23,17,16]
# pm25_min = [16,10,11,12,15,12,11,17,13,9,14,19,14,10,8,9,11]
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
area = ['서울',	'부산',	'대구',	'인천',	'광주',	'대전',	'울산',	'세종',	'경기',	'강원',	'충북',	'충남',	'전북',	'전남',	'경북',	'경남',	'제주']
pm25_avg = [20,13,15,20,19,16,14,18,20,14,19,23,23,14,15,13,14]
pm25_max = [22,18,18,30,23,20,16,19,27,18,26,29,30,27,23,17,16]
pm25_min = [16,10,11,12,15,12,11,17,13,9,14,19,14,10,8,9,11]

# %%
print(area)
# Out:
# ['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주']

# %% [markdown]
# ## 데이터프레임으로 변환
# * **pd.DataFrame()**

# %% [markdown]
# ###  리스트를 데이터프레임으로 변환

# %%
import pandas as pd

# %%
df = pd.DataFrame(area)
df
# Out:
#      0
# 0   서울
# 1   부산
# 2   대구
# 3   인천
# 4   광주
# 5   대전
# 6   울산
# 7   세종
# 8   경기
# 9   강원
# 10  충북
# 11  충남
# 12  전북
# 13  전남
# 14  경북
# 15  경남
# 16  제주

# %%
df['평균'] = pm25_avg
df['최대'] = pm25_max
df['최소'] = pm25_min
df
# Out:
#      0  평균  최대  최소
# 0   서울  20  22  16
# 1   부산  13  18  10
# 2   대구  15  18  11
# 3   인천  20  30  12
# 4   광주  19  23  15
# 5   대전  16  20  12
# 6   울산  14  16  11
# 7   세종  18  19  17
# 8   경기  20  27  13
# 9   강원  14  18   9
# 10  충북  19  26  14
# 11  충남  23  29  19
# 12  전북  23  30  14
# 13  전남  14  27  10
# 14  경북  15  23   8
# 15  경남  13  17   9
# 16  제주  14  16  11

# %% [markdown]
# ### 딕션너리를 데이터프레임으로 변환
# * 딕션너리 키 : 열(column)
# * 딕션너리 값 : 행(row)

# %%
df = pd.DataFrame(dt)
df

# %%
df = pd.DataFrame()
df['area'] = area
df['avg'] = pm25_avg
df['max'] = pm25_max
df['min'] = pm25_min
df

# %%
temp = list(zip(area,pm25_avg,pm25_max,pm25_min))
print(temp)

df2 = pd.DataFrame(temp)
df2.columns = ['area', 'avg', 'max', 'min']
df2
# Out:
# [('서울', 20, 22, 16), ('부산', 13, 18, 10), ('대구', 15, 18, 11), ('인천', 20, 30, 12), ('광주', 19, 23, 15), ('대전', 16, 20, 12), ('울산', 14, 16, 11), ('세종', 18, 19, 17), ('경기', 20, 27, 13), ('강원', 14, 18, 9), ('충북', 19, 26, 14), ('충남', 23, 29, 19), ('전북', 23, 30, 14), ('전남', 14, 27, 10), ('경북', 15, 23, 8), ('경남', 13, 17, 9), ('제주', 14, 16, 11)]
#    area  avg  max  min
# 0    서울   20   22   16
# 1    부산   13   18   10
# 2    대구   15   18   11
# 3    인천   20   30   12
# 4    광주   19   23   15
# 5    대전   16   20   12
# 6    울산   14   16   11
# 7    세종   18   19   17
# 8    경기   20   27   13
# 9    강원   14   18    9
# 10   충북   19   26   14
# 11   충남   23   29   19
# 12   전북   23   30   14
# 13   전남   14   27   10
# 14   경북   15   23    8
# 15   경남   13   17    9
# 16   제주   14   16   11

# %%
# 열 이름주기
dtz = list(zip(area,pm25_avg,pm25_max,pm25_min ))

df = pd.DataFrame(dtz)
df.columns = ['area', 'avg', 'max', 'min']
df

# %% [markdown]
# ## 외부 데이터 가져오기
# + csv 읽기
#  - 한글 파일명을 사용할 경우 : df = pd.read_csv(‘파일명‘, engine='python')
#  - 파일 내용 한글이 깨지는 경우 : df = pd.read_csv(‘파일명‘, engine='python', encoding='cp949')
# >
# ```
# df = pd.read_csv(‘파일명‘)
# ```
#
# + 엑셀 읽기
#  - 한글 파일명을 사용할 경우 : df = pd.read_excel(‘파일명‘)
# >
# ```
# df = pd.read_excel(‘파일명‘)
# ```

# %%
#지역별주간별_초미세먼지.csv 가져오기 
df = pd.read_csv('/content/drive/MyDrive/파이썬특강/python2021/data/지역별주간별_초미세먼지.csv', engine='python', encoding='cp949')
df
# Out:
#    지역   주간평균   최고값   최저값
# 0   서울     20    22    16
# 1   부산     13    18    10
# 2   대구     15    18    11
# 3   인천     20    30    12
# 4   광주     19    23    15
# 5   대전     16    20    12
# 6   울산     14    16    11
# 7   세종     18    19    17
# 8   경기     20    27    13
# 9   강원     14    18     9
# 10  충북     19    26    14
# 11  충남     23    29    19
# 12  전북     23    30    14
# 13  전남     14    27    10
# 14  경북     15    23     8
# 15  경남     13    17     9
# 16  제주     14    16    11

# %% [markdown]
# ## 데이터프레임(DataFrame) 살펴보기
# * 데이터프레임의 정보 : **df.info()**
#  - 데이터프레임에 대한 전반적인 정보
#  - 데이터프레임을 구성하는 행과 열의 크기, 컬럼명, 컬럼을 구성하는 값의 자료형 등을 출력
# + 데이터프레임의 크기 확인 : **df.shape 속성**
#  - (행, 열) 크기를 확인하기
#  - 행의 개수 : len(데이터프레임), len(.index), .shape[0]
#  - 열의 개수 : len(.column), .shape[1]
# + 데이터프레임의 원소의 총개수 : **df.size 속성**
# + 데이터프레임 개수 확인 :**df.count()**
#  - Null이 아닌 행의 개수 확인
#  - axis='columns' : Null이 아닌 열의 개수 확인
# * 데이터프레임의 인덱스
#  + 열의 인덱스 : **df.colums**
#  + 행의 인덱스 : **df.index**
#  + **데이터프레임의 인덱스 변경**
#    - 열인덱스 명 변경 : df.column = [열명인덱스]
#    - 열항목 중 하나를 인덱스로 사용 : df.set_index(열명)
#    - 인덱스를 일반 데이터 열로 전환 : df.reset_index()

# %%
#데이터프레임의 정보
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      17 non-null     object
#  1   주간평균    17 non-null     int64
#  2   최고값     17 non-null     int64
#  3   최저값     17 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 672.0+ bytes

# %%
# 행
df.index
# Out:
# RangeIndex(start=0, stop=17, step=1)

# %%
#열
df.columns
# Out:
# Index(['지역 ', '주간평균 ', '최고값 ', '최저값 '], dtype='object')

# %%
#데이터프레임의 크기 확인
print('데이터프레임 (행, 열) : ', df.shape)
print('데이터프레임 행 개수 len : ', len(df) )
print('데이터프레임 행 개수 len : ', len(df.index) )
print('데이터프레임 행 개수 shape : ', df.shape[0] )
print('데이터프레임 열 개수 len : ', len(df.columns) )
print('데이터프레임 열 개수 shape : ', df.shape[1] )
# Out:
# 데이터프레임 (행, 열) :  (17, 4)
# 데이터프레임 행 개수 len :  17
# 데이터프레임 행 개수 len :  17
# 데이터프레임 행 개수 shape :  17
# 데이터프레임 열 개수 len :  4
# 데이터프레임 열 개수 shape :  4

# %%
#데이터프레임 각 열의개수 확인
print(df.count())
print('-'*20)
print(df.count(axis='columns'))
# Out:
# 지역       17
# 주간평균     17
# 최고값      17
# 최저값      17
# dtype: int64
# --------------------
# 0     4
# 1     4
# 2     4
# 3     4
# 4     4
# 5     4
# 6     4
# 7     4
# 8     4
# 9     4
# 10    4
# 11    4
# 12    4
# 13    4
# 14    4
# 15    4
# 16    4
# dtype: int64

# %%
#데이터프레임의 원소의 총개수
print(df.size)
# Out:
# 68

# %%
#데이터프레임의 인덱스
print('열인덱스 : ', df.columns)
print('행인덱스 :', df.index)
# Out:
# 열인덱스 :  Index(['지역 ', '주간평균 ', '최고값 ', '최저값 '], dtype='object')
# 행인덱스 : RangeIndex(start=0, stop=17, step=1)

# %%
df['최고값 ']
# Out:
# 0     22
# 1     18
# 2     18
# 3     30
# 4     23
# 5     20
# 6     16
# 7     19
# 8     27
# 9     18
# 10    26
# 11    29
# 12    30
# 13    27
# 14    23
# 15    17
# 16    16
# Name: 최고값 , dtype: int64

# %%
#열명의 공백 제거 
df.columns = [item.strip() for item in df.columns]
df.columns
# Out:
# Index(['지역', '주간평균', '최고값', '최저값'], dtype='object')

# %%
#위
df.head(4)
# Out:
#    지역  주간평균  최고값  최저값
# 0  서울    20   22   16
# 1  부산    13   18   10
# 2  대구    15   18   11
# 3  인천    20   30   12

# %%
#밑
df.tail(2)
# Out:
#     지역  주간평균  최고값  최저값
# 15  경남    13   17    9
# 16  제주    14   16   11

# %%
df['최고값']
# Out:
# 0     22
# 1     18
# 2     18
# 3     30
# 4     23
# 5     20
# 6     16
# 7     19
# 8     27
# 9     18
# 10    26
# 11    29
# 12    30
# 13    27
# 14    23
# 15    17
# 16    16
# Name: 최고값, dtype: int64

# %%
#지역 컬럼을 행 인덱스로 지정
df = df.set_index('지역')
df
# Out:
#     주간평균  최고값  최저값
# 지역
# 서울    20   22   16
# 부산    13   18   10
# 대구    15   18   11
# 인천    20   30   12
# 광주    19   23   15
# 대전    16   20   12
# 울산    14   16   11
# 세종    18   19   17
# 경기    20   27   13
# 강원    14   18    9
# 충북    19   26   14
# 충남    23   29   19
# 전북    23   30   14
# 전남    14   27   10
# 경북    15   23    8
# 경남    13   17    9
# 제주    14   16   11

# %%
df.index
# Out:
# Index(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북', '충남',
#        '전북', '전남', '경북', '경남', '제주'],
#       dtype='object', name='지역')

# %%
#인덱스를 일반 데이터 열로 전환
df = df.reset_index()
df
# Out:
#     지역  주간평균  최고값  최저값
# 0   서울    20   22   16
# 1   부산    13   18   10
# 2   대구    15   18   11
# 3   인천    20   30   12
# 4   광주    19   23   15
# 5   대전    16   20   12
# 6   울산    14   16   11
# 7   세종    18   19   17
# 8   경기    20   27   13
# 9   강원    14   18    9
# 10  충북    19   26   14
# 11  충남    23   29   19
# 12  전북    23   30   14
# 13  전남    14   27   10
# 14  경북    15   23    8
# 15  경남    13   17    9
# 16  제주    14   16   11

# %% [markdown]
# ## **데이터프레임 인덱싱(indexing)과 슬라이싱(slicing)**

# %%
df = df.set_index('지역')
df.head()

# %% [markdown]
# ### df[]
#  + 특정 열 가져오기 : df[열인덱스], df[열인덱스 리스트]
#  + 특정 행 가져오기 : df[시작행인덱스:종료행인덱스]

# %%
df.columns
# Out:
# Index(['주간평균', '최고값', '최저값'], dtype='object')

# %%
#특정 열 가져오기
df['주간평균']
# Out:
# 지역
# 서울    20
# 부산    13
# 대구    15
# 인천    20
# 광주    19
# 대전    16
# 울산    14
# 세종    18
# 경기    20
# 강원    14
# 충북    19
# 충남    23
# 전북    23
# 전남    14
# 경북    15
# 경남    13
# 제주    14
# Name: 주간평균, dtype: int64

# %%
df[['주간평균']]
# Out:
#     주간평균
# 지역
# 서울    20
# 부산    13
# 대구    15
# 인천    20
# 광주    19
# 대전    16
# 울산    14
# 세종    18
# 경기    20
# 강원    14
# 충북    19
# 충남    23
# 전북    23
# 전남    14
# 경북    15
# 경남    13
# 제주    14

# %%
df[['주간평균','최고값']]
# Out:
#     주간평균  최고값
# 지역
# 서울    20   22
# 부산    13   18
# 대구    15   18
# 인천    20   30
# 광주    19   23
# 대전    16   20
# 울산    14   16
# 세종    18   19
# 경기    20   27
# 강원    14   18
# 충북    19   26
# 충남    23   29
# 전북    23   30
# 전남    14   27
# 경북    15   23
# 경남    13   17
# 제주    14   16

# %%
df['부산']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '부산'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-9980a53cc428> in <module>()
# ----> 1 df['부산']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: '부산'

# %%
#특정행 가져오기
df['부산':'인천']
# Out:
#     주간평균  최고값  최저값
# 지역
# 부산    13   18   10
# 대구    15   18   11
# 인천    20   30   12

# %% [markdown]
# ### df.loc[행인덱스, 열인덱스]
# * 특정 열 가져오기 : df.loc[:, 열인덱스]
# * 특정 행 가져오기 : df.loc[행인덱스, :]
# * 특정 항목 가져오기 : df.loc[행인덱스, 열인덱스]

# %%
df.head()
# Out:
#     주간평균  최고값  최저값
# 지역
# 서울    20   22   16
# 부산    13   18   10
# 대구    15   18   11
# 인천    20   30   12
# 광주    19   23   15

# %%
df[['최저값']]
# Out:
#     최저값
# 지역
# 서울   16
# 부산   10
# 대구   11
# 인천   12
# 광주   15
# 대전   12
# 울산   11
# 세종   17
# 경기   13
# 강원    9
# 충북   14
# 충남   19
# 전북   14
# 전남   10
# 경북    8
# 경남    9
# 제주   11

# %%
#특정 열 가져오기
df.loc[:,'최고값' : '최저값'] 

#df.loc[:,:] 모두 데리고오기
#df.loc[:'대구',:'최곳값']
# Out:
#     최고값  최저값
# 지역
# 서울   22   16
# 부산   18   10
# 대구   18   11
# 인천   30   12
# 광주   23   15
# 대전   20   12
# 울산   16   11
# 세종   19   17
# 경기   27   13
# 강원   18    9
# 충북   26   14
# 충남   29   19
# 전북   30   14
# 전남   27   10
# 경북   23    8
# 경남   17    9
# 제주   16   11

# %%
#필요한 행만
df.loc[:, ['주간평균', '최저값']]
# Out:
#     주간평균  최저값
# 지역
# 서울    20   16
# 부산    13   10
# 대구    15   11
# 인천    20   12
# 광주    19   15
# 대전    16   12
# 울산    14   11
# 세종    18   17
# 경기    20   13
# 강원    14    9
# 충북    19   14
# 충남    23   19
# 전북    23   14
# 전남    14   10
# 경북    15    8
# 경남    13    9
# 제주    14   11

# %%
df.loc[:, '주간평균':'최저값']
# Out:
#     주간평균  최고값  최저값
# 지역
# 서울    20   22   16
# 부산    13   18   10
# 대구    15   18   11
# 인천    20   30   12
# 광주    19   23   15
# 대전    16   20   12
# 울산    14   16   11
# 세종    18   19   17
# 경기    20   27   13
# 강원    14   18    9
# 충북    19   26   14
# 충남    23   29   19
# 전북    23   30   14
# 전남    14   27   10
# 경북    15   23    8
# 경남    13   17    9
# 제주    14   16   11

# %%
#특정 행 가져오기
df.loc['부산',:]
# Out:
# 주간평균    13
# 최고값     18
# 최저값     10
# Name: 부산, dtype: int64

# %%
df.loc[['부산', '인천'], :]
# Out:
#     주간평균  최고값  최저값
# 지역
# 부산    13   18   10
# 인천    20   30   12

# %%
df.loc['부산':'인천', :]
# Out:
#     주간평균  최고값  최저값
# 지역
# 부산    13   18   10
# 대구    15   18   11
# 인천    20   30   12

# %%
#특정 항목 가져오기
df.loc['부산', '주간평균']
# Out:
# 13

# %%
df.loc[['부산','인천'],['주간평균', '최저값']]
# Out:
#     주간평균  최저값
# 지역
# 부산    13   10
# 인천    20   12

# %%
df.loc['부산':'인천','주간평균':'최저값']
# Out:
#     주간평균  최고값  최저값
# 지역
# 부산    13   18   10
# 대구    15   18   11
# 인천    20   30   12

# %%
#울산의 주간평균과 최고값

df.loc[['울산'],'주간평균':'최고값']
# Out:
#     주간평균  최고값
# 지역
# 울산    14   16

# %% [markdown]
# ### df.iloc[행인덱스순서, 열인덱스순서]
# * 특정 열 가져오기 : df.loc[:, 열인덱스순서]
# * 특정 행 가져오기 : df.loc[행인덱스순서, :]
# * 특정 항목 가져오기 : df.loc[행인덱스순서, 열인덱스순서]

# %%
df.index
# Out:
# Index(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북', '충남',
#        '전북', '전남', '경북', '경남', '제주'],
#       dtype='object', name='지역')

# %%
df.columns
# Out:
# Index(['주간평균', '최고값', '최저값'], dtype='object')

# %%
#특정 열 가져오기
#df.loc[:, '최저값'] 
df.iloc[:, 2]

# %%
#df.loc[:, ['주간평균', '최저값']]
df.iloc[:, [0, 2]]

# %%
#df.loc[:, '주간평균':'최저값']
df.iloc[:, 0:2]

# %%
#특정 행 가져오기
#df.loc['부산',:]
df.iloc[1,:]

# %%
#df.loc[['부산', '인천'], :]
df.iloc[[1, 3], :]

# %%
#df.loc['부산':'인천', :]
df.iloc[1:4, :]

# %%
#특정 항목 가져오기
#df.loc['부산', '주간평균']
df.iloc[1, 0]

# %%
#df.loc[['부산','인천'],['주간평균', '최저값']]
df.iloc[[0,3],[0, 2]]

# %%
#df.loc['부산':'인천','주간평균':'최저값']
df.iloc[1:4,0:3]

# %% [markdown]
# ## **데이터프레임(DataFrame) 기본 조회와 기초 통계 메소드**
# * head(n) : 상위 n개 조회, n생략 시 5개 조회
# + tail(n) : 하위 n개 조회, n생략 시 5개 조회
# + describe() : 요약 통계량 계산
# + mean() : 평균
# + max() : 최대
# + min() : 최소
# + std()  : 표준편차

# %%
df.head(2)
# Out:
#     주간평균  최고값  최저값
# 지역
# 서울    20   22   16
# 부산    13   18   10

# %%
df.tail(2)
# Out:
#     주간평균  최고값  최저값
# 지역
# 경남    13   17    9
# 제주    14   16   11

# %%
# 통게치
df.describe()
# Out:
#             주간평균        최고값        최저값
# count  17.000000  17.000000  17.000000
# mean   17.058824  22.294118  12.411765
# std     3.399827   5.009550   3.063063
# min    13.000000  16.000000   8.000000
# 25%    14.000000  18.000000  10.000000
# 50%    16.000000  22.000000  12.000000
# 75%    20.000000  27.000000  14.000000
# max    23.000000  30.000000  19.000000

# %% [markdown]
# ## 자주사용되는 메소드

# %% [markdown]
# ### 행열 전환 : df.T

# %%
df2 = df.T
df2
# Out:
# 지역    서울  부산  대구  인천  광주  대전  울산  세종  경기  강원  충북  충남  전북  전남  경북  경남  제주
# 주간평균  20  13  15  20  19  16  14  18  20  14  19  23  23  14  15  13  14
# 최고값   22  18  18  30  23  20  16  19  27  18  26  29  30  27  23  17  16
# 최저값   16  10  11  12  15  12  11  17  13   9  14  19  14  10   8   9  11

# %% [markdown]
# ### 정렬
# + 행열 인덱스 정렬 : df.sort_index(axis=n), n생략 또는 0:행, 1:열
# + 행렬 값 정렬 : df.sort_values()

# %%
df
# Out:
#     주간평균  최고값  최저값
# 지역
# 서울    20   22   16
# 부산    13   18   10
# 대구    15   18   11
# 인천    20   30   12
# 광주    19   23   15
# 대전    16   20   12
# 울산    14   16   11
# 세종    18   19   17
# 경기    20   27   13
# 강원    14   18    9
# 충북    19   26   14
# 충남    23   29   19
# 전북    23   30   14
# 전남    14   27   10
# 경북    15   23    8
# 경남    13   17    9
# 제주    14   16   11

# %%
#ㄱ.ㄴ.ㄷ순으로
df.sort_index()
# Out:
#     주간평균  최고값  최저값
# 지역
# 강원    14   18    9
# 경기    20   27   13
# 경남    13   17    9
# 경북    15   23    8
# 광주    19   23   15
# 대구    15   18   11
# 대전    16   20   12
# 부산    13   18   10
# 서울    20   22   16
# 세종    18   19   17
# 울산    14   16   11
# 인천    20   30   12
# 전남    14   27   10
# 전북    23   30   14
# 제주    14   16   11
# 충남    23   29   19
# 충북    19   26   14

# %%
df.sort_values('주간평균', ascending=False)
# Out:
#     주간평균  최고값  최저값
# 지역
# 충남    23   29   19
# 전북    23   30   14
# 서울    20   22   16
# 경기    20   27   13
# 인천    20   30   12
# 광주    19   23   15
# 충북    19   26   14
# 세종    18   19   17
# 대전    16   20   12
# 대구    15   18   11
# 경북    15   23    8
# 울산    14   16   11
# 강원    14   18    9
# 전남    14   27   10
# 제주    14   16   11
# 부산    13   18   10
# 경남    13   17    9

# %% [markdown]
# ### 문자열 처리
# * df['열명'].str

# %%
data = pd.read_excel('/content/drive/MyDrive/파이썬특강/python2021/data/특성화학과정보_컴퓨터.xlsx')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   No             137 non-null    int64
#  1   학과명            137 non-null    object
#  2   대학명            137 non-null    object
#  3   폐과             0 non-null      float64
#  4   학과 특성화명        137 non-null    object
#  5   특성화 구분         137 non-null    object
#  6   특성화분류 (대-중-소)  137 non-null    object
#  7   Unnamed: 7     137 non-null    object
#  8   Unnamed: 8     137 non-null    object
#  9   구분             137 non-null    object
#  10  학교종류           137 non-null    object
#  11  지역             137 non-null    object
#  12  설립유형           137 non-null    object
#  13  주야구분           137 non-null    object
#  14  표준분류계열(대)      137 non-null    object
#  15  표준분류계열(중)      137 non-null    object
#  16  표준분류계열(소)      137 non-null    object
#  17  관심             0 non-null      float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 19.4+ KB

# %%
s = '수원과학대학교'
s[]
# Out:
# '학대학교'

# %%
data['대학명'].str[:-3]
# Out:
# 0        우송
# 1        세명
# 2        중앙
# 3        목원
# 4        상명
#        ...
# 132    수원과학
# 133      청암
# 134      부천
# 135      거제
# 136    울산과학
# Name: 대학명, Length: 137, dtype: object

# %%
data.head()
# Out:
#    No                학과명    대학명  폐과  ... 표준분류계열(대)  표준분류계열(중)  표준분류계열(소)  관심
# 0   1  IT융합학부 컴퓨터정보·보안전공  우송대학교 NaN  ...      공학계열  전기・전자・컴퓨터  전산학・컴퓨터공학 NaN
# 1   2              디자인학부  세명대학교 NaN  ...     예체능계열         미술        디자인 NaN
# 2   3            소프트웨어학부  중앙대학교 NaN  ...      공학계열  전기・전자・컴퓨터  전산학・컴퓨터공학 NaN
# 3   4        융합컴퓨터·미디어학부  목원대학교 NaN  ...      공학계열  전기・전자・컴퓨터  전산학・컴퓨터공학 NaN
# 4   5   전기전자컴퓨터학부 컴퓨터과학과  상명대학교 NaN  ...      공학계열  전기・전자・컴퓨터  전산학・컴퓨터공학 NaN
#
# [5 rows x 18 columns]

# %%
data['대학명'].str[:-3]
# Out:
# 0        우송
# 1        세명
# 2        중앙
# 3        목원
# 4        상명
#        ...
# 132    수원과학
# 133      청암
# 134      부천
# 135      거제
# 136    울산과학
# Name: 대학명, Length: 137, dtype: object

# %%
area = list(data['지역'].drop_duplicates())
area
# Out:
# ['대전',
#  '충북',
#  '서울',
#  '강원',
#  '경북',
#  '전북',
#  '전남',
#  '부산',
#  '광주',
#  '경기',
#  '인천',
#  '충남',
#  '경남',
#  '대구',
#  '제주',
#  '세종',
#  '울산']

# %%
my = data[(data['지역'] == '서울'| (data['지역'] == '울산') | (data['지역'] == '부산')]
my['대학명']
# Out:
#   File "<ipython-input-98-cae92064c4cd>", line 1
#     my = data[(data['지역'] == '서울'| (data['지역'] == '울산') | (data['지역'] == '부산')]
#                                                                               ^
# SyntaxError: invalid syntax

# %%
s = data[data['지역'] == '서울']
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 2 to 116
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   No             19 non-null     int64
#  1   학과명            19 non-null     object
#  2   대학명            19 non-null     object
#  3   폐과             0 non-null      float64
#  4   학과 특성화명        19 non-null     object
#  5   특성화 구분         19 non-null     object
#  6   특성화분류 (대-중-소)  19 non-null     object
#  7   Unnamed: 7     19 non-null     object
#  8   Unnamed: 8     19 non-null     object
#  9   구분             19 non-null     object
#  10  학교종류           19 non-null     object
#  11  지역             19 non-null     object
#  12  설립유형           19 non-null     object
#  13  주야구분           19 non-null     object
#  14  표준분류계열(대)      19 non-null     object
#  15  표준분류계열(중)      19 non-null     object
#  16  표준분류계열(소)      19 non-null     object
#  17  관심             0 non-null      float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 2.8+ KB

# %% [markdown]
# ### 그룹화
# * 데이터를 그룹별로 분류
# * df.groupby(인수)
#   + 열 또는 열의 리스트
#   + 행 인덱스
# * 그룹 연산 메소드
#   + size, count: 그룹 데이터의 갯수
#   + mean, median, min, max: 그룹 데이터의 평균, 중앙값, 최소, 최대
#   + sum, prod, std, var, quantile : 그룹 데이터의 합계, 곱, 표준편차, 분산, 사분위수
#   + first, last: 그룹 데이터 중 가장 첫번째 데이터와 가장 나중 데이터

# %%
datag = data.groupby('지역')[['대학명']].count()
datag.sort_values('대학명', ascending=False)

# %%
data.groupby('지역')[['대학명']].count()
# Out:
#     대학명
# 지역
# 강원    4
# 경기   21
# 경남    5
# 경북    8
# 광주    6
# 대구    9
# 대전   11
# 부산   11
# 서울   19
# 세종    1
# 울산    1
# 인천    6
# 전남    5
# 전북    6
# 제주    5
# 충남    7
# 충북   12

# %%
datag.sort_values('대학명', ascending=False)
# Out:
#     No  학과명  대학명  폐과  학과 특성화명  ...  주야구분  표준분류계열(대)  표준분류계열(중)  표준분류계열(소)  관심
# 지역                             ...
# 경기  21   21   21   0       21  ...    21         21         21         21   0
# 서울  19   19   19   0       19  ...    19         19         19         19   0
# 충북  12   12   12   0       12  ...    12         12         12         12   0
# 대전  11   11   11   0       11  ...    11         11         11         11   0
# 부산  11   11   11   0       11  ...    11         11         11         11   0
# 대구   9    9    9   0        9  ...     9          9          9          9   0
# 경북   8    8    8   0        8  ...     8          8          8          8   0
# 충남   7    7    7   0        7  ...     7          7          7          7   0
# 광주   6    6    6   0        6  ...     6          6          6          6   0
# 인천   6    6    6   0        6  ...     6          6          6          6   0
# 전북   6    6    6   0        6  ...     6          6          6          6   0
# 경남   5    5    5   0        5  ...     5          5          5          5   0
# 전남   5    5    5   0        5  ...     5          5          5          5   0
# 제주   5    5    5   0        5  ...     5          5          5          5   0
# 강원   4    4    4   0        4  ...     4          4          4          4   0
# 세종   1    1    1   0        1  ...     1          1          1          1   0
# 울산   1    1    1   0        1  ...     1          1          1          1   0
#
# [17 rows x 17 columns]

# %%
pusan.describe()
# Out:
#              경쟁률       교과총점         등급         추합           년도
# count  48.000000  48.000000  48.000000  48.000000    48.000000
# mean   10.052141  97.921065   2.952184   6.458333  2019.500000
# std     3.962890   0.943159   0.510788   5.107184     1.129865
# min     5.333333  93.890000   1.970000   0.000000  2018.000000
# 25%     7.406250  97.855161   2.577500   4.000000  2018.750000
# 50%     8.965000  98.216789   2.858100   5.000000  2019.500000
# 75%    11.702500  98.440472   3.163450   8.000000  2020.250000
# max    24.500000  99.030000   4.220000  30.000000  2021.000000

# %%
pusan = pd.read_csv('/content/drive/MyDrive/파이썬특강/python2021/data/부산대1821.csv', engine='python', encoding='cp949')
pusan
# Out:
#         학과        경쟁률       교과총점        등급  추합    년도
# 0   국어국문학과   5.888889  97.932600  2.800311   9  2018
# 1   중어중문학과   5.333333  98.089866  2.901277   5  2018
# 2   일어일문학과   7.000000  98.480690  2.519110   4  2018
# 3   영어영문학과   6.800000  98.702021  2.297742  16  2018
# 4   불어불문학과   6.818182  95.883833  3.930366   4  2018
# 5   독어독문학과   7.083333  97.750645  3.233800   6  2018
# 6   노어노문학과   7.625000  97.590116  2.866200   5  2018
# 7     한문학과  10.428571  97.420700  3.464450   2  2018
# 8   언어정보학과   7.125000  98.511175  2.488587   5  2018
# 9      사학과   6.714286  98.640671  2.359071   5  2018
# 10     철학과   6.625000  95.400840  3.878200   0  2018
# 11    고고학과   6.571429  97.911414  3.088300   3  2018
# 12  국어국문학과  12.000000  98.636170  2.800311   7  2019
# 13  중어중문학과  13.500000  98.730520  2.901277   4  2019
# 14  일어일문학과  10.214286  98.332385  2.519110   8  2019
# 15  영어영문학과  11.800000  98.795900  2.297742  30  2019
# 16  불어불문학과  24.500000  98.102091  3.930366   5  2019
# 17  독어독문학과  19.333333  98.223577  3.233800   4  2019
# 18  노어노문학과  14.600000  98.471890  2.866200   5  2019
# 19    한문학과  14.000000  98.038633  3.464450   6  2019
# 20  언어정보학과   9.375000  97.984816  2.488587   3  2019
# 21     사학과   7.500000  98.648875  2.359071   7  2019
# 22     철학과  21.600000  98.278000  3.878200   5  2019
# 23    고고학과  11.857143  98.303700  3.088300   9  2019
# 24  국어국문학과   6.910000  98.510000  2.480000  12  2020
# 25  중어중문학과  12.500000  97.470000  3.100000   4  2020
# 26  일어일문학과   7.600000  98.030000  2.970000   6  2020
# 27  영어영문학과   6.200000  97.000000  3.570000   6  2020
# 28  불어불문학과   8.220000  98.210000  2.790000   4  2020
# 29  독어독문학과   8.170000  97.390000  3.020000   4  2020
# 30  노어노문학과   7.800000  97.890000  3.100000   4  2020
# 31    한문학과   9.110000  93.890000  3.920000   1  2020
# 32  언어정보학과   8.700000  98.390000  2.610000   8  2020
# 33     사학과  11.630000  98.260000  2.740000   6  2020
# 34     철학과   9.130000  96.860000  3.140000   0  2020
# 35    고고학과   9.570000  96.150000  4.220000   2  2020
# 36  국어국문학과   8.820000  98.620000  2.370000  11  2021
# 37  중어중문학과   7.920000  97.930000  3.050000   9  2021
# 38  일어일문학과   7.570000  98.160000  2.840000  11  2021
# 39  영어영문학과  11.130000  99.030000  1.970000  15  2021
# 40  불어불문학과  15.920000  98.430000  2.570000  11  2021
# 41  독어독문학과  11.920000  98.240000  2.760000  15  2021
# 42  노어노문학과   9.900000  98.420000  2.580000   6  2021
# 43    한문학과   9.440000  97.430000  3.370000   4  2021
# 44  언어정보학과  11.440000  98.350000  2.650000   4  2021
# 45     사학과   8.380000  98.290000  2.690000   0  2021
# 46     철학과  11.670000  98.090000  2.850000   8  2021
# 47    고고학과   8.560000  98.310000  2.690000   2  2021

# %%
pusan.groupby('학과').mean().loc[:, :'추합']
# Out:
#               경쟁률       교과총점        등급     추합
# 학과
# 고고학과     9.139643  97.668779  3.271650   4.00
# 국어국문학과   8.404722  98.424692  2.612655   9.75
# 노어노문학과   9.981250  98.093001  2.853100   5.00
# 독어독문학과  11.626667  97.901055  3.061900   7.25
# 불어불문학과  13.864545  97.656481  3.305183   6.00
# 사학과      8.556071  98.459887  2.537035   4.50
# 언어정보학과   9.160000  98.308998  2.559293   5.00
# 영어영문학과   8.982500  98.381980  2.533871  16.75
# 일어일문학과   8.096071  98.250769  2.712055   7.25
# 중어중문학과   9.813333  98.055097  2.988138   5.50
# 철학과     12.256250  97.157210  3.436600   3.25
# 한문학과    10.744643  96.694833  3.554725   3.25

# %% [markdown]
# ### 시계열 자료
# * **pd.to_datetime()** : 날짜/시간을 나타내는 문자열을 자동으로 datetime 자료형으로 변환
# * **dt 접근자** : datetime 자료형 시리즈에는 dt 접근자가 있어 datetime 자료형이 가진 몇가지 유용한 속성과 메서드를 사용
#   +  year, month, day, weekday 등의 속성을 이용하면 년, 월, 일, 요일 정보 추출
#
# dt 접근자 | 내용
# -------------------|------------------
# .dt.date         | YYYY-MM-DD(문자)
# .dt.year         | 연(4자리숫자)
# .dt.month        | 월(숫자)
# .dt.month_name() | 월(문자)
# .dt.day          | 일(숫자)
# .dt.time         | HH:MM:SS(문자)
# .dt.hour         | 시(숫자)
# .dt.minute       | 분(숫자)
# .dt.second       | 초(숫자)
# .dt.quarter       | 분기(숫자)
# .dt.day_name()  | 요일이름(문자)
# .dt.weekday       | 요일숫자(0-월, 1-화) (=dayofweek)
# .dt.weekofyear    | 연 기준 몇주째(숫자) (=week)
# .dt.dayofyear     | 연 기준 몇일째(숫자)
# .dt.days_in_month | 월 일수(숫자) (=daysinmonth)

# %%
data = pd.read_csv('/content/drive/MyDrive/파이썬특강/python2021/data/air.csv', encoding='cp949')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 591 entries, 0 to 590
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      591 non-null    object
#  1   PM10_1  589 non-null    object
#  2   PM10_2  589 non-null    float64
#  3   PM25_1  589 non-null    object
#  4   PM25_2  589 non-null    float64
#  5   O3_1    589 non-null    object
#  6   O3_2    589 non-null    float64
#  7   NO2_1   589 non-null    object
#  8   NO2_2   589 non-null    float64
#  9   CO_1    589 non-null    object
#  10  Co_2    589 non-null    float64
#  11  SO2_1   589 non-null    object
#  12  SO2_2   589 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 60.1+ KB

# %%
data.head()
# Out:
#               날짜 PM10_1  PM10_2 PM25_1  PM25_2  ...  NO2_2  CO_1 Co_2  SO2_1  SO2_2
# 0  2021-04-25:15     좋음    23.0     좋음    10.0  ...  0.008    좋음  0.3     좋음  0.002
# 1  2021-04-25:14     좋음    24.0     좋음    10.0  ...  0.007    좋음  0.3     좋음  0.002
# 2  2021-04-25:13     좋음    27.0     좋음     8.0  ...  0.009    좋음  0.3     좋음  0.002
# 3  2021-04-25:12     좋음    23.0     좋음     9.0  ...  0.009    좋음  0.3     좋음  0.002
# 4  2021-04-25:11     좋음    27.0     좋음    12.0  ...  0.007    좋음  0.3     좋음  0.002
#
# [5 rows x 13 columns]

# %%
data['day'] = data['날짜'].str[:-3]
data.head()
# Out:
#               날짜 PM10_1  PM10_2 PM25_1  ...  Co_2 SO2_1  SO2_2         day
# 0  2021-04-25:15     좋음    23.0     좋음  ...   0.3    좋음  0.002  2021-04-25
# 1  2021-04-25:14     좋음    24.0     좋음  ...   0.3    좋음  0.002  2021-04-25
# 2  2021-04-25:13     좋음    27.0     좋음  ...   0.3    좋음  0.002  2021-04-25
# 3  2021-04-25:12     좋음    23.0     좋음  ...   0.3    좋음  0.002  2021-04-25
# 4  2021-04-25:11     좋음    27.0     좋음  ...   0.3    좋음  0.002  2021-04-25
#
# [5 rows x 14 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of                 날짜 PM10_1  PM10_2 PM25_1  ...  Co_2 SO2_1  SO2_2         day
# 0    2021-04-25:15     좋음    23.0     좋음  ...   0.3    좋음  0.002  2021-04-25
# 1    2021-04-25:14     좋음    24.0     좋음  ...   0.3    좋음  0.002  2021-04-25
# 2    2021-04-25:13     좋음    27.0     좋음  ...   0.3    좋음  0.002  2021-04-25
# 3    2021-04-25:12     좋음    23.0     좋음  ...   0.3    좋음  0.002  2021-04-25
# 4    2021-04-25:11     좋음    27.0     좋음  ...   0.3    좋음  0.002  2021-04-25
# ..             ...    ...     ...    ...  ...   ...   ...    ...         ...
# 586  2021-04-01:05     보통    38.0     보통  ...   0.5    좋음  0.003  2021-04-01
# 587  2021-04-01:04     보통    36.0     보통  ...   0.5    좋음  0.003  2021-04-01
# 588  2021-04-01:03     보통    41.0     보통  ...   0.6    좋음  0.003  2021-04-01
# 589  2021-04-01:02     보통    37.0     보통  ...   0.6    좋음  0.003  2021-04-01
# 590  2021-04-01:01     보통    39.0     보통  ...   0.6    좋음  0.003  2021-04-01
#
# [591 rows x 14 columns]>

# %%
data['day'] = pd.to_datetime(data['day'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 591 entries, 0 to 590
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      591 non-null    object
#  1   PM10_1  589 non-null    object
#  2   PM10_2  589 non-null    float64
#  3   PM25_1  589 non-null    object
#  4   PM25_2  589 non-null    float64
#  5   O3_1    589 non-null    object
#  6   O3_2    589 non-null    float64
#  7   NO2_1   589 non-null    object
#  8   NO2_2   589 non-null    float64
#  9   CO_1    589 non-null    object
#  10  Co_2    589 non-null    float64
#  11  SO2_1   589 non-null    object
#  12  SO2_2   589 non-null    float64
#  13  day     591 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), object(7)
# memory usage: 64.8+ KB

# %%
data['day'] = data['날짜'].str[:-3]
data['day'] = pd.to_datetime(data['day'])
data.info()

# %%
data['요일'] = data['day'].dt.day_name()
data.head()
# Out:
#               날짜 PM10_1  PM10_2 PM25_1  ...  SO2_1  SO2_2        day      요일
# 0  2021-04-25:15     좋음    23.0     좋음  ...     좋음  0.002 2021-04-25  Sunday
# 1  2021-04-25:14     좋음    24.0     좋음  ...     좋음  0.002 2021-04-25  Sunday
# 2  2021-04-25:13     좋음    27.0     좋음  ...     좋음  0.002 2021-04-25  Sunday
# 3  2021-04-25:12     좋음    23.0     좋음  ...     좋음  0.002 2021-04-25  Sunday
# 4  2021-04-25:11     좋음    27.0     좋음  ...     좋음  0.002 2021-04-25  Sunday
#
# [5 rows x 15 columns]

# %% [markdown]
# ---
# ## 해결문제
#
#
# ---
#
# 대학알리미 사이트에서 표준분류 정보 검색을 통해 '컴퓨터'관련 학과를 검색한 정보를 받아서 자료를 분석하시오.
#
# 1.'대학명','학과명', '지역', '설립유형', '표준분류계열(대)'
#
# 2.부산지역의 국립 대학 추출

# %%
data = pd.read_excel('/표준분류 정보.xlsx')
data
# Out:
#       No                학과명          대학명  구분  ... 표준분류계열(중) 표준분류계열(소) 특성화학과  관심
# 0      1      미술·디자인학부(디자인)        가천대학교  본교  ...        미술       디자인   NaN NaN
# 1      2            CG디자인학과     가톨릭관동대학교  본교  ...        미술       디자인   NaN NaN
# 2      3  예체능학부 유니버설아트디자인전공        강남대학교  본교  ...        미술       디자인   NaN NaN
# 3      4         조형예술・디자인학과      강릉원주대학교  본교  ...        미술       디자인   NaN NaN
# 4      5              디자인학과        강원대학교  본교  ...        미술       디자인   NaN NaN
# ..   ...                ...          ...  ..  ...       ...       ...   ...  ..
# 621  622        패션액세서리디자인전공  홍익대학교 패션대학원  본교  ...        미술       디자인   NaN NaN
# 622  623          패션뷰티디자인전공  홍익대학교 패션대학원  본교  ...        미술       디자인   NaN NaN
# 623  624          패션뷰티디자인전공  홍익대학교 패션대학원  본교  ...        미술       디자인   NaN NaN
# 624  625            패션디자인전공  홍익대학교 패션대학원  본교  ...        미술       디자인   NaN NaN
# 625  626            패션디자인전공  홍익대학교 패션대학원  본교  ...        미술       디자인   NaN NaN
#
# [626 rows x 14 columns]

# %%
data['대학명']
# Out:
# 0            가천대학교
# 1         가톨릭관동대학교
# 2            강남대학교
# 3          강릉원주대학교
# 4            강원대학교
#           ...
# 621    홍익대학교 패션대학원
# 622    홍익대학교 패션대학원
# 623    홍익대학교 패션대학원
# 624    홍익대학교 패션대학원
# 625    홍익대학교 패션대학원
# Name: 대학명, Length: 626, dtype: object

# %%
data.head(50)
# Out:
#     No                학과명         대학명     구분  ... 표준분류계열(중) 표준분류계열(소) 특성화학과  관심
# 0    1      미술·디자인학부(디자인)       가천대학교     본교  ...        미술       디자인   NaN NaN
# 1    2            CG디자인학과    가톨릭관동대학교     본교  ...        미술       디자인   NaN NaN
# 2    3  예체능학부 유니버설아트디자인전공       강남대학교     본교  ...        미술       디자인   NaN NaN
# 3    4         조형예술・디자인학과     강릉원주대학교     본교  ...        미술       디자인   NaN NaN
# 4    5              디자인학과       강원대학교     본교  ...        미술       디자인   NaN NaN
# 5    6          생활조형디자인학과       강원대학교  제2캠퍼스  ...        미술       디자인   NaN NaN
# 6    7            멀티디자인학과       강원대학교  제2캠퍼스  ...        미술       디자인   NaN NaN
# 7    8        커뮤니케이션디자인학과       건국대학교     본교  ...        미술       디자인   NaN NaN
# 8    9            산업디자인학과       건국대학교     본교  ...        미술       디자인   NaN NaN
# 9   10            의상디자인학과       건국대학교     본교  ...        미술       디자인   NaN NaN
# 10  11            산업디자인학과  건국대학교(글로컬)     분교  ...        미술       디자인   NaN NaN
# 11  12            패션디자인학과  건국대학교(글로컬)     분교  ...        미술       디자인   NaN NaN
# 12  13            실내디자인학과  건국대학교(글로컬)     분교  ...        미술       디자인   NaN NaN
# 13  14              디자인학부  건국대학교(글로컬)     분교  ...        미술       디자인   NaN NaN
# 14  15          시각영상디자인학과  건국대학교(글로컬)     분교  ...        미술       디자인   NaN NaN
# 15  16            산업디자인전공       경기대학교     본교  ...        미술       디자인   NaN NaN
# 16  17          시각정보디자인전공       경기대학교     본교  ...        미술       디자인   NaN NaN
# 17  18            디자인비즈학부       경기대학교     본교  ...        미술       디자인   NaN NaN
# 18  19        장신구・금속디자인전공       경기대학교     본교  ...        미술       디자인   NaN NaN
# 19  20            산업디자인학과       경남대학교     본교  ...        미술       디자인   NaN NaN
# 20  21              디자인학과       경동대학교  제4캠퍼스  ...        미술       디자인   NaN NaN
# 21  22              디자인학과       경북대학교     본교  ...        미술       디자인   NaN NaN
# 22  23  섬유패션디자인학부 패션디자인전공       경북대학교     본교  ...        미술       디자인   NaN NaN
# 23  24          텍스타일디자인학과     경상국립대학교     본교  ...        미술       디자인   NaN NaN
# 24  25           산업디자인학전공       경성대학교     본교  ...        미술       디자인   NaN NaN
# 25  26           시각디자인학전공       경성대학교     본교  ...        미술       디자인   NaN NaN
# 26  27              디자인학부       경성대학교     본교  ...        미술       디자인   NaN NaN
# 27  28            패션디자인학과       경성대학교     본교  ...        미술       디자인   NaN NaN
# 28  29        디지털미디어디자인학과       경일대학교     본교  ...        미술       디자인   NaN NaN
# 29  30      게임엔터테인먼트디자인전공       경주대학교     본교  ...        미술       디자인   NaN NaN
# 30  31          산업토탈디자인전공       경주대학교     본교  ...        미술       디자인   NaN NaN
# 31  32            시각디자인전공       경주대학교     본교  ...        미술       디자인   NaN NaN
# 32  33     3D디자인게임애니메이션학부       경주대학교     본교  ...        미술       디자인   NaN NaN
# 33  34          2D디자인웹툰학부       경주대학교     본교  ...        미술       디자인   NaN NaN
# 34  35          환경조경디자인학과       경희대학교     본교  ...        미술       디자인   NaN NaN
# 35  36            산업디자인학과       경희대학교     본교  ...        미술       디자인   NaN NaN
# 36  37            시각디자인학과       경희대학교     본교  ...        미술       디자인   NaN NaN
# 37  38            의류디자인학과       경희대학교     본교  ...        미술       디자인   NaN NaN
# 38  39         시각미디어디자인전공    경희사이버대학교     본교  ...        미술       디자인   NaN NaN
# 39  40            산업디자인전공    경희사이버대학교     본교  ...        미술       디자인   NaN NaN
# 40  41             시각디자인과       계명대학교     본교  ...        미술       디자인   NaN NaN
# 41  42             패션디자인과       계명대학교     본교  ...        미술       디자인   NaN NaN
# 42  43           텍스타일디자인과       계명대학교     본교  ...        미술       디자인   NaN NaN
# 43  44             산업디자인과       계명대학교     본교  ...        미술       디자인   NaN NaN
# 44  45            융합디자인학과       고신대학교     본교  ...        미술       디자인   NaN NaN
# 45  46          가구리빙디자인학과       공주대학교     본교  ...        미술       디자인   NaN NaN
# 46  47            제품디자인전공       공주대학교     본교  ...        미술       디자인   NaN NaN
# 47  48           세라믹디자인학과       공주대학교     본교  ...        미술       디자인   NaN NaN
# 48  49          시각정보디자인전공       공주대학교     본교  ...        미술       디자인   NaN NaN
# 49  50        패션・주얼리디자인학부       광주대학교     본교  ...        미술       디자인   NaN NaN
#
# [50 rows x 14 columns]

# %%
s = data[data['지역'] == '서울']
s.head(10)
# Out:
#     No          학과명       대학명  구분  ... 표준분류계열(중) 표준분류계열(소) 특성화학과  관심
# 7    8  커뮤니케이션디자인학과     건국대학교  본교  ...        미술       디자인   NaN NaN
# 8    9      산업디자인학과     건국대학교  본교  ...        미술       디자인   NaN NaN
# 9   10      의상디자인학과     건국대학교  본교  ...        미술       디자인   NaN NaN
# 34  35    환경조경디자인학과     경희대학교  본교  ...        미술       디자인   NaN NaN
# 35  36      산업디자인학과     경희대학교  본교  ...        미술       디자인   NaN NaN
# 36  37      시각디자인학과     경희대학교  본교  ...        미술       디자인   NaN NaN
# 37  38      의류디자인학과     경희대학교  본교  ...        미술       디자인   NaN NaN
# 38  39   시각미디어디자인전공  경희사이버대학교  본교  ...        미술       디자인   NaN NaN
# 39  40      산업디자인전공  경희사이버대학교  본교  ...        미술       디자인   NaN NaN
# 53  54      의상디자인학과     국민대학교  본교  ...        미술       디자인   NaN NaN
#
# [10 rows x 14 columns]

# %%
s = data[data['설립유형'] == '국립']
s.head(20)
# Out:
#       No                학과명        대학명     구분  ... 표준분류계열(중) 표준분류계열(소) 특성화학과  관심
# 3      4         조형예술・디자인학과    강릉원주대학교     본교  ...        미술       디자인   NaN NaN
# 4      5              디자인학과      강원대학교     본교  ...        미술       디자인   NaN NaN
# 5      6          생활조형디자인학과      강원대학교  제2캠퍼스  ...        미술       디자인   NaN NaN
# 6      7            멀티디자인학과      강원대학교  제2캠퍼스  ...        미술       디자인   NaN NaN
# 21    22              디자인학과      경북대학교     본교  ...        미술       디자인   NaN NaN
# 22    23  섬유패션디자인학부 패션디자인전공      경북대학교     본교  ...        미술       디자인   NaN NaN
# 23    24          텍스타일디자인학과    경상국립대학교     본교  ...        미술       디자인   NaN NaN
# 45    46          가구리빙디자인학과      공주대학교     본교  ...        미술       디자인   NaN NaN
# 46    47            제품디자인전공      공주대학교     본교  ...        미술       디자인   NaN NaN
# 47    48           세라믹디자인학과      공주대학교     본교  ...        미술       디자인   NaN NaN
# 48    49          시각정보디자인전공      공주대학교     본교  ...        미술       디자인   NaN NaN
# 59    60            산업디자인학과      군산대학교     본교  ...        미술       디자인   NaN NaN
# 114  115            공업디자인학과      부경대학교     본교  ...        미술       디자인   NaN NaN
# 115  116            패션디자인학과      부경대학교     본교  ...        미술       디자인   NaN NaN
# 116  117            시각디자인학과      부경대학교     본교  ...        미술       디자인   NaN NaN
# 117  118              디자인학과      부산대학교     본교  ...        미술       디자인   NaN NaN
# 134  135     디자인학과(시각디자인전공)  서울과학기술대학교     본교  ...        미술       디자인   NaN NaN
# 135  136     디자인학과(산업디자인전공)  서울과학기술대학교     본교  ...        미술       디자인   NaN NaN
# 159  160            패션디자인학과      순천대학교     본교  ...        미술       디자인   NaN NaN
# 200  201              디자인학과      전남대학교     본교  ...        미술       디자인   NaN NaN
#
# [20 rows x 14 columns]
